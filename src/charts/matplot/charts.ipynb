# %% [markdown]
# # Step 1 - Import required libraries

# %%
import pandas as pd
from matplotlib import pyplot as plt

# %% [markdown]
# ## Step 2 - Import Dataset
#
# **About mtcars data**
#
# The data was extracted from the 1974 Motor Trend US magazine, and comprises fuel consumption and 10 (12) aspects of automible design and performance for 32 automibiles (1973-74 models).

# %%
mtcars = pd.read_csv('') # add the relative or absolute path where the csv file is located.
mtcars

# %% [markdown]
# ## Step 3 - Understand Data
#
# ### Step 3.1 - Perform Initial Analysis

# %%
mtcars.shape

# %%
mtcars.dtypes

# %%
mtcars.describe()

# %% [markdown]
# ## Step 3.2 - Perform data visualization for better understanding

# %% [markdown]
# ### 3.2.1 Univariate Analysis
#
# Finding insights from **single** feature

# %%
# !pip install matplotlib

# %%
plt.hist(mtcars['mpg']) # Speaks about the distribution of one continuous data
plt.title('MPG vs Frequency')
plt.xlabel('MPG')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# ### Types of Data
#
# | Data | What's it for |
# |:-----|:---------|
# | Discrete | Countable, finite, can't be measured |
# | Continuous | Range of data, can be measured |

# %%
# with seaborn

# !pip install seaborn

# %%
import seaborn as sns

# %%
sns.histplot(mtcars, x = 'mpg')

# %%
mtcars.isna().sum()

# %%
# with plotly
# !pip install plotly

# %%
import plotly as ply

# %%
# ply.hist_frame(mtcars['mpg'])
# ^ have some ValueError

# %% [markdown]
# ### 3.2.2 Bivariate Analysis
#
# For comparing **two** features

# %%
mtcars.head()

# %%
plt.bar(mtcars['vs'], height=mtcars['mpg'])

# %%
# option 2 with seaborn

sns.barplot(mtcars, x='cyl', y='mpg') # x - should be discrete | y - should be continuous
plt.title('CYL vs MPG')
plt.show()

# %% [markdown]
# ### 3.3.3 - Multivariate Analysis

# %%
sns.pairplot(data = mtcars)
plt.show()
